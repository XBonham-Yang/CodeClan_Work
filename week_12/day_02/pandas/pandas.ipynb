# %% [markdown]
# # Pandas

# %% [markdown]
# ## Plan
#
# 1. read in a dataset
# 2. getting some immediate information about the data
# 3. subset our data
#     1. by column
#     1. by row (filtering)
#     1. getting max value locations (`.idxmin()`, `idxmax()`)
# 4. sort our data
# 5. make changes to our data
#     1. new column names
#     1. change column values
#     1. create new columns
# 6. calculate summary stats
#     1. for the whole dataset
#     1. for groups
# 7. dealing with missing values

# %%
# read in data 
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('data/life_expectancy_and_income_missing.csv')

# %%
# getting some immediate information about the data
df.columns
# Out:
# Index(['country', 'year', 'fertility_rate', 'income_per_person',
#        'life_expectancy'],
#       dtype='object')

# %%
df.shape
# Out:
# (22080, 5)

# %%
df.head()
# Out:
#        country  year  fertility_rate  income_per_person  life_expectancy
# 0  Afghanistan  1900             7.0             1090.0             29.4
# 1  Afghanistan  1901             7.0             1110.0              NaN
# 2  Afghanistan  1902             7.0             1120.0             29.5
# 3  Afghanistan  1903             7.0             1140.0             29.6
# 4  Afghanistan  1904             7.0             1160.0             29.7

# %%
df.describe()
#distribution of the data 
# only numeric data
# Out:
#                year  fertility_rate  income_per_person  life_expectancy
# count  22080.000000    22080.000000       22066.000000     21896.000000
# mean    1959.500000        4.840770        7608.560274        52.725449
# std       34.640598        1.916428       13450.013474        16.743644
# min     1900.000000        1.120000         312.000000         1.100000
# 25%     1929.750000        2.980000        1370.000000        35.800000
# 50%     1959.500000        5.450000        2880.000000        53.800000
# 75%     1989.250000        6.500000        7710.000000        68.300000
# max     2019.000000        8.870000      179000.000000        85.100000

# %%
df.describe(include = 'all')
# this also gives you other things
# Out:
#             country          year  fertility_rate  income_per_person  \
# count         22080  22080.000000    22080.000000       22066.000000
# unique          184           NaN             NaN                NaN
# top     Afghanistan           NaN             NaN                NaN
# freq            120           NaN             NaN                NaN
# mean            NaN   1959.500000        4.840770        7608.560274
# std             NaN     34.640598        1.916428       13450.013474
# min             NaN   1900.000000        1.120000         312.000000
# 25%             NaN   1929.750000        2.980000        1370.000000
# 50%             NaN   1959.500000        5.450000        2880.000000
# 75%             NaN   1989.250000        6.500000        7710.000000
# max             NaN   2019.000000        8.870000      179000.000000
#
#         life_expectancy
# count      21896.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean          52.725449
# std           16.743644
# min            1.100000
# 25%           35.800000
# 50%           53.800000
# 75%           68.300000
# max           85.100000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22080 entries, 0 to 22079
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            22080 non-null  object
#  1   year               22080 non-null  int64
#  2   fertility_rate     22080 non-null  float64
#  3   income_per_person  22066 non-null  float64
#  4   life_expectancy    21896 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 862.6+ KB

# %%
df.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22080 entries, 0 to 22079
# Columns: 5 entries, country to life_expectancy
# dtypes: float64(3), int64(1), object(1)
# memory usage: 862.6+ KB

# %% [markdown]
# Excercise
# For the exercises in this lesson we'll use a dataset about occupational prestige. Here is some information on the variables contained in the data.
#
# education Average years of education of occupational incumbents, years, in 1971.
# income Average income of incumbents, dollars, in 1971.
# women Percentage of incumbents who are women.
# prestige Pineo-Porter prestige score for occupation, from a social survey conducted in the mid-1960s.
# census Canadian Census occupational code.
# type Type of occupation. A factor with levels (note: out of order): bc, Blue Collar; prof, Professional, Managerial, and Technical; wc, White Collar.
#
# Read in the file prestige_occupation.csv. Save it as an object called occupation_prestige.
# How many rows and columns are in the data?
# What is the average (mean) value for the column prestige (hint: you can use describe to answer this).

# %%
df_op = pd.read_csv('data/prestige_occupation.csv')

# %%
df_op.shape
# Out:
# (102, 7)

# %%
df_op["prestige"].describe()
# Out:
# count    102.000000
# mean      46.833333
# std       17.204486
# min       14.800000
# 25%       35.225000
# 50%       43.600000
# 75%       59.275000
# max       87.200000
# Name: prestige, dtype: float64

# %%
#subsetting data 
df.country
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 22075       Zimbabwe
# 22076       Zimbabwe
# 22077       Zimbabwe
# 22078       Zimbabwe
# 22079       Zimbabwe
# Name: country, Length: 22080, dtype: object

# %%
df['country']
# series
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 22075       Zimbabwe
# 22076       Zimbabwe
# 22077       Zimbabwe
# 22078       Zimbabwe
# 22079       Zimbabwe
# Name: country, Length: 22080, dtype: object

# %%
df[['year', 'country']]
# dataframe
# Out:
#        year      country
# 0      1900  Afghanistan
# 1      1901  Afghanistan
# 2      1902  Afghanistan
# 3      1903  Afghanistan
# 4      1904  Afghanistan
# ...     ...          ...
# 22075  2015     Zimbabwe
# 22076  2016     Zimbabwe
# 22077  2017     Zimbabwe
# 22078  2018     Zimbabwe
# 22079  2019     Zimbabwe
#
# [22080 rows x 2 columns]

# %%
df.loc[:, ['country', 'year']]
# Out:
#            country  year
# 0      Afghanistan  1900
# 1      Afghanistan  1901
# 2      Afghanistan  1902
# 3      Afghanistan  1903
# 4      Afghanistan  1904
# ...            ...   ...
# 22075     Zimbabwe  2015
# 22076     Zimbabwe  2016
# 22077     Zimbabwe  2017
# 22078     Zimbabwe  2018
# 22079     Zimbabwe  2019
#
# [22080 rows x 2 columns]

# %%
mask = df.country == 'Japan'
df.loc[mask]
# Out:
#      country  year  fertility_rate  income_per_person  life_expectancy
# 9720   Japan  1900            4.69             1860.0             38.7
# 9721   Japan  1901            5.01             1900.0              NaN
# 9722   Japan  1902            4.97             1780.0             39.0
# 9723   Japan  1903            4.83             1880.0             39.1
# 9724   Japan  1904            4.61             1870.0             39.2
# ...      ...   ...             ...                ...              ...
# 9835   Japan  2015            1.44            37800.0             84.1
# 9836   Japan  2016            1.46            38100.0             84.2
# 9837   Japan  2017            1.47            38900.0             84.2
# 9838   Japan  2018            1.48            39300.0             84.4
# 9839   Japan  2019            1.50            39700.0             84.5
#
# [120 rows x 5 columns]

# %%
df.loc[mask, ['country', 'year', 'life_expectancy']]
# Out:
#      country  year  life_expectancy
# 9720   Japan  1900             38.7
# 9721   Japan  1901              NaN
# 9722   Japan  1902             39.0
# 9723   Japan  1903             39.1
# 9724   Japan  1904             39.2
# ...      ...   ...              ...
# 9835   Japan  2015             84.1
# 9836   Japan  2016             84.2
# 9837   Japan  2017             84.2
# 9838   Japan  2018             84.4
# 9839   Japan  2019             84.5
#
# [120 rows x 3 columns]

# %%
# mask is condition 1 and condition 2
mask = (df.country == 'Japan') & (df.year > 2000)

# %%
df.loc[mask]
# Out:
#      country  year  fertility_rate  income_per_person  life_expectancy
# 9821   Japan  2001            1.31            33900.0             81.7
# 9822   Japan  2002            1.30            33900.0             82.0
# 9823   Japan  2003            1.30            34300.0             82.1
# 9824   Japan  2004            1.30            35100.0             82.3
# 9825   Japan  2005            1.31            35700.0             82.3
# 9826   Japan  2006            1.32            36100.0             82.6
# 9827   Japan  2007            1.33            36700.0             82.8
# 9828   Japan  2008            1.34            36300.0             82.9
# 9829   Japan  2009            1.36            34300.0             83.1
# 9830   Japan  2010            1.37            35800.0             83.1
# 9831   Japan  2011            1.39            35800.0             82.9
# 9832   Japan  2012            1.40            36400.0             83.4
# 9833   Japan  2013            1.42            37100.0             83.6
# 9834   Japan  2014            1.43            37300.0             83.8
# 9835   Japan  2015            1.44            37800.0             84.1
# 9836   Japan  2016            1.46            38100.0             84.2
# 9837   Japan  2017            1.47            38900.0             84.2
# 9838   Japan  2018            1.48            39300.0             84.4
# 9839   Japan  2019            1.50            39700.0             84.5

# %%
#mask = df.country == 'Japan' or (df.country == 'Italy')
mask_1 = df.country.isin(['Japan','Italy'])
df.loc[mask_1]
# Out:
#      country  year  fertility_rate  income_per_person  life_expectancy
# 9480   Italy  1900            4.53             3780.0             41.7
# 9481   Italy  1901            4.49             3840.0              NaN
# 9482   Italy  1902            4.46             3900.0             43.0
# 9483   Italy  1903            4.43             3940.0             43.1
# 9484   Italy  1904            4.44             4010.0             44.4
# ...      ...   ...             ...                ...              ...
# 9835   Japan  2015            1.44            37800.0             84.1
# 9836   Japan  2016            1.46            38100.0             84.2
# 9837   Japan  2017            1.47            38900.0             84.2
# 9838   Japan  2018            1.48            39300.0             84.4
# 9839   Japan  2019            1.50            39700.0             84.5
#
# [240 rows x 5 columns]

# %%
#min and max row locations 
#saving subssets 
i = df.life_expectancy.idxmin()
i
# Out:
# 16338

# %%
df.loc[i]
# Out:
# country               Samoa
# year                   1918
# fertility_rate         6.98
# income_per_person    2050.0
# life_expectancy         1.1
# Name: 16338, dtype: object

# %%
df.loc[df.life_expectancy.idxmax()]
# Out:
# country              Singapore
# year                      2019
# fertility_rate            1.27
# income_per_person      90100.0
# life_expectancy           85.1
# Name: 17279, dtype: object

# %%
# saving 
my_list = [0,1,2,3,4]

# %%
my_list_view = my_list
my_list_view.append(10)
my_list
# Out:
# [0, 1, 2, 3, 4, 10]

# %%
my_list_copy = my_list.copy()
my_list_copy.remove(10)
print(my_list)
print(my_list_copy)
# Out:
# [0, 1, 2, 3, 4, 10]
# [0, 1, 2, 3, 4]

# %%
mask = (df.country == 'Japan') & (df.year > 2000)
jp_df = df.loc[mask, ['country', 'year', 'life_expectancy']].copy()

# %%
jp_df
# Out:
#      country  year  life_expectancy
# 9821   Japan  2001             81.7
# 9822   Japan  2002             82.0
# 9823   Japan  2003             82.1
# 9824   Japan  2004             82.3
# 9825   Japan  2005             82.3
# 9826   Japan  2006             82.6
# 9827   Japan  2007             82.8
# 9828   Japan  2008             82.9
# 9829   Japan  2009             83.1
# 9830   Japan  2010             83.1
# 9831   Japan  2011             82.9
# 9832   Japan  2012             83.4
# 9833   Japan  2013             83.6
# 9834   Japan  2014             83.8
# 9835   Japan  2015             84.1
# 9836   Japan  2016             84.2
# 9837   Japan  2017             84.2
# 9838   Japan  2018             84.4
# 9839   Japan  2019             84.5

# %% [markdown]
# Make a new data frame called, job_incomes, that has just the "job", "type" and "income" column from occupation_prestige. Make sure the columns appear in the order we have given.

# %%
df_op[["job", "type", "income"]]
# Out:
#                      job  type  income
# 0     gov.administrators  prof   12351
# 1       general.managers  prof   25879
# 2            accountants  prof    9271
# 3    purchasing.officers  prof    8865
# 4               chemists  prof    8403
# ..                   ...   ...     ...
# 97           bus.drivers    bc    5562
# 98          taxi.drivers    bc    4224
# 99          longshoremen    bc    4753
# 100          typesetters    bc    6462
# 101          bookbinders    bc    3617
#
# [102 rows x 3 columns]

# %% [markdown]
# Task - 5 minutes
# Return 2 rows at the same time, with the highest and lowest income!
# [Hint - you can pass a list as an argument for loc()] (edited)

# %%
mk = (df_op.income == max(df_op.income))|(df_op.income == min(df_op.income))
df_op.loc[mk]
# Out:
#                  job  education  income  women  prestige  census  type
# 1   general.managers      12.26   25879   4.02      69.1    1130  prof
# 62       babysitters       9.46     611  96.53      25.9    6147   NaN

# %%
df_op.loc[[df_op.income.idxmax(), df_op.income.idxmin()]]
# Out:
#                  job  education  income  women  prestige  census  type
# 1   general.managers      12.26   25879   4.02      69.1    1130  prof
# 62       babysitters       9.46     611  96.53      25.9    6147   NaN

# %%
#sorting 
df.sort_values('year')
# Out:
#                    country  year  fertility_rate  income_per_person  \
# 0              Afghanistan  1900            7.00             1090.0
# 3360              Cameroon  1900            5.54              924.0
# 480    Antigua and Barbuda  1900            4.63             1300.0
# 11280            Lithuania  1900            4.96             2740.0
# 11160                Libya  1900            7.20             2470.0
# ...                    ...   ...             ...                ...
# 14159                Niger  2019            7.07              954.0
# 14039            Nicaragua  2019            2.12             4620.0
# 13919          New Zealand  2019            1.96            36500.0
# 13679                Nepal  2019            2.02             2880.0
# 22079             Zimbabwe  2019            3.53             2390.0
#
#        life_expectancy
# 0                 29.4
# 3360              29.7
# 480               33.8
# 11280             41.7
# 11160             34.7
# ...                ...
# 14159             63.2
# 14039             79.2
# 13919             81.9
# 13679             71.5
# 22079             62.0
#
# [22080 rows x 5 columns]

# %%
df.sort_values(['year','country'])
# Out:
#                    country  year  fertility_rate  income_per_person  \
# 0              Afghanistan  1900            7.00             1090.0
# 120                Albania  1900            4.60             1220.0
# 240                Algeria  1900            6.99             1750.0
# 360                 Angola  1900            7.00              958.0
# 480    Antigua and Barbuda  1900            4.63             1300.0
# ...                    ...   ...             ...                ...
# 21599            Venezuela  2019            2.25             9720.0
# 21719              Vietnam  2019            1.94             6970.0
# 21839                Yemen  2019            3.69             2340.0
# 21959               Zambia  2019            4.81             3700.0
# 22079             Zimbabwe  2019            3.53             2390.0
#
#        life_expectancy
# 0                 29.4
# 120               35.4
# 240               30.2
# 360               29.0
# 480               33.8
# ...                ...
# 21599             75.1
# 21719             74.7
# 21839             68.1
# 21959             64.0
# 22079             62.0
#
# [22080 rows x 5 columns]

# %% [markdown]
# sort the demo data by descending

# %%
df.sort_values('life_expectancy', ascending = False)
# Out:
#          country  year  fertility_rate  income_per_person  life_expectancy
# 17279  Singapore  2019            1.27            90100.0             85.1
# 17278  Singapore  2018            1.26            90100.0             85.0
# 17277  Singapore  2017            1.25            87800.0             84.8
# 17276  Singapore  2016            1.25            84700.0             84.7
# 9839       Japan  2019            1.50            39700.0             84.5
# ...          ...   ...             ...                ...              ...
# 21481  Venezuela  1901            5.64             2000.0              NaN
# 21601    Vietnam  1901            4.66              969.0              NaN
# 21721      Yemen  1901            6.88             1170.0              NaN
# 21841     Zambia  1901            6.71              847.0              NaN
# 21961   Zimbabwe  1901            6.75              981.0              NaN
#
# [22080 rows x 5 columns]

# %%
df.sort_values(['year','country'], inplace = True)
df
# Out:
#                    country  year  fertility_rate  income_per_person  \
# 0              Afghanistan  1900            7.00             1090.0
# 120                Albania  1900            4.60             1220.0
# 240                Algeria  1900            6.99             1750.0
# 360                 Angola  1900            7.00              958.0
# 480    Antigua and Barbuda  1900            4.63             1300.0
# ...                    ...   ...             ...                ...
# 21599            Venezuela  2019            2.25             9720.0
# 21719              Vietnam  2019            1.94             6970.0
# 21839                Yemen  2019            3.69             2340.0
# 21959               Zambia  2019            4.81             3700.0
# 22079             Zimbabwe  2019            3.53             2390.0
#
#        life_expectancy
# 0                 29.4
# 120               35.4
# 240               30.2
# 360               29.0
# 480               33.8
# ...                ...
# 21599             75.1
# 21719             74.7
# 21839             68.1
# 21959             64.0
# 22079             62.0
#
# [22080 rows x 5 columns]

# %%
df.rename(columns = {'old':"new"})

# %%
df.rename(columns= {'income_per_person':'GDP'}, inplace = True)
df
# Out:
#                    country  year  fertility_rate     GDP  life_expectancy
# 0              Afghanistan  1900            7.00  1090.0             29.4
# 120                Albania  1900            4.60  1220.0             35.4
# 240                Algeria  1900            6.99  1750.0             30.2
# 360                 Angola  1900            7.00   958.0             29.0
# 480    Antigua and Barbuda  1900            4.63  1300.0             33.8
# ...                    ...   ...             ...     ...              ...
# 21599            Venezuela  2019            2.25  9720.0             75.1
# 21719              Vietnam  2019            1.94  6970.0             74.7
# 21839                Yemen  2019            3.69  2340.0             68.1
# 21959               Zambia  2019            4.81  3700.0             64.0
# 22079             Zimbabwe  2019            3.53  2390.0             62.0
#
# [22080 rows x 5 columns]

# %%
df.rename(columns = {'country':"place", 'year':'time'})
# Out:
#                      place  time  fertility_rate     GDP  life_expectancy
# 0              Afghanistan  1900            7.00  1090.0             29.4
# 120                Albania  1900            4.60  1220.0             35.4
# 240                Algeria  1900            6.99  1750.0             30.2
# 360                 Angola  1900            7.00   958.0             29.0
# 480    Antigua and Barbuda  1900            4.63  1300.0             33.8
# ...                    ...   ...             ...     ...              ...
# 21599            Venezuela  2019            2.25  9720.0             75.1
# 21719              Vietnam  2019            1.94  6970.0             74.7
# 21839                Yemen  2019            3.69  2340.0             68.1
# 21959               Zambia  2019            4.81  3700.0             64.0
# 22079             Zimbabwe  2019            3.53  2390.0             62.0
#
# [22080 rows x 5 columns]

# %%
# changeing col 
df.fertility_rate = df.fertility_rate * 4 
df
# Out:
#                    country  year  fertility_rate     GDP  life_expectancy
# 0              Afghanistan  1900          112.00  1090.0             29.4
# 120                Albania  1900           73.60  1220.0             35.4
# 240                Algeria  1900          111.84  1750.0             30.2
# 360                 Angola  1900          112.00   958.0             29.0
# 480    Antigua and Barbuda  1900           74.08  1300.0             33.8
# ...                    ...   ...             ...     ...              ...
# 21599            Venezuela  2019           36.00  9720.0             75.1
# 21719              Vietnam  2019           31.04  6970.0             74.7
# 21839                Yemen  2019           59.04  2340.0             68.1
# 21959               Zambia  2019           76.96  3700.0             64.0
# 22079             Zimbabwe  2019           56.48  2390.0             62.0
#
# [22080 rows x 5 columns]

# %%
df["f_rate"] = df.fertility_rate / 4 
df
# Out:
#                    country  year  fertility_rate     GDP  life_expectancy  \
# 0              Afghanistan  1900          112.00  1090.0             29.4
# 120                Albania  1900           73.60  1220.0             35.4
# 240                Algeria  1900          111.84  1750.0             30.2
# 360                 Angola  1900          112.00   958.0             29.0
# 480    Antigua and Barbuda  1900           74.08  1300.0             33.8
# ...                    ...   ...             ...     ...              ...
# 21599            Venezuela  2019           36.00  9720.0             75.1
# 21719              Vietnam  2019           31.04  6970.0             74.7
# 21839                Yemen  2019           59.04  2340.0             68.1
# 21959               Zambia  2019           76.96  3700.0             64.0
# 22079             Zimbabwe  2019           56.48  2390.0             62.0
#
#        f_rate
# 0       28.00
# 120     18.40
# 240     27.96
# 360     28.00
# 480     18.52
# ...       ...
# 21599    9.00
# 21719    7.76
# 21839   14.76
# 21959   19.24
# 22079   14.12
#
# [22080 rows x 6 columns]

# %%
# creating new col

# %%
df.assign(years_since_1900 = df.year - 1900)
# doesn't change the original df 
df_1900 =(
    df
    .assign(years_since_1900 = df.year - 1900, # create
           fertillity_rate = round(df.fertility_rate)) # modify 
    .copy()
)
df_1900
# Out:
#                    country  year  fertility_rate     GDP  life_expectancy  \
# 0              Afghanistan  1900          112.00  1090.0             29.4
# 120                Albania  1900           73.60  1220.0             35.4
# 240                Algeria  1900          111.84  1750.0             30.2
# 360                 Angola  1900          112.00   958.0             29.0
# 480    Antigua and Barbuda  1900           74.08  1300.0             33.8
# ...                    ...   ...             ...     ...              ...
# 21599            Venezuela  2019           36.00  9720.0             75.1
# 21719              Vietnam  2019           31.04  6970.0             74.7
# 21839                Yemen  2019           59.04  2340.0             68.1
# 21959               Zambia  2019           76.96  3700.0             64.0
# 22079             Zimbabwe  2019           56.48  2390.0             62.0
#
#        f_rate  years_since_1900  fertillity_rate
# 0       28.00                 0            112.0
# 120     18.40                 0             74.0
# 240     27.96                 0            112.0
# 360     28.00                 0            112.0
# 480     18.52                 0             74.0
# ...       ...               ...              ...
# 21599    9.00               119             36.0
# 21719    7.76               119             31.0
# 21839   14.76               119             59.0
# 21959   19.24               119             77.0
# 22079   14.12               119             56.0
#
# [22080 rows x 8 columns]

# %% [markdown]
# Change the "income" column in prestige to be in 1000s of dollars, rather than dollars.

# %%
df_op_income = df_op.assign(income = df_op.income/1000).copy()
df_op_income
# Out:
#                      job  education  income  women  prestige  census  type
# 0     gov.administrators      13.11  12.351  11.16      68.8    1113  prof
# 1       general.managers      12.26  25.879   4.02      69.1    1130  prof
# 2            accountants      12.77   9.271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42   8.865   9.11      56.8    1175  prof
# 4               chemists      14.62   8.403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58   5.562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93   4.224   3.59      25.1    9173    bc
# 99          longshoremen       8.37   4.753    NaN      26.1    9313    bc
# 100          typesetters      10.00   6.462  13.58      42.2    9511    bc
# 101          bookbinders       8.55   3.617  70.87      35.2    9517    bc
#
# [102 rows x 7 columns]

# %%
# summarising the data

# %%
df.describe()
# mean min ....
# Out:
#                year  fertility_rate            GDP  life_expectancy  \
# count  22080.000000    22080.000000   22066.000000     21896.000000
# mean    1959.500000       77.452326    7608.560274        52.725449
# std       34.640598       30.662850   13450.013474        16.743644
# min     1900.000000       17.920000     312.000000         1.100000
# 25%     1929.750000       47.680000    1370.000000        35.800000
# 50%     1959.500000       87.200000    2880.000000        53.800000
# 75%     1989.250000      104.000000    7710.000000        68.300000
# max     2019.000000      141.920000  179000.000000        85.100000
#
#              f_rate
# count  22080.000000
# mean      19.363082
# std        7.665713
# min        4.480000
# 25%       11.920000
# 50%       21.800000
# 75%       26.000000
# max       35.480000

# %%
df.fertility_rate.min()
# Out:
# 17.92

# %%
mask = df.life_expectancy < df.life_expectancy.median()
df.loc[mask]
# Out:
#                         country  year  fertility_rate     GDP  \
# 0                   Afghanistan  1900          112.00  1090.0
# 120                     Albania  1900           73.60  1220.0
# 240                     Algeria  1900          111.84  1750.0
# 360                      Angola  1900          112.00   958.0
# 480         Antigua and Barbuda  1900           74.08  1300.0
# ...                         ...   ...             ...     ...
# 3836   Central African Republic  2016           77.92   731.0
# 11036                   Lesotho  2016           49.44  2940.0
# 3837   Central African Republic  2017           76.80   754.0
# 3838   Central African Republic  2018           75.52   775.0
# 3839   Central African Republic  2019           74.40   794.0
#
#        life_expectancy  f_rate
# 0                 29.4   28.00
# 120               35.4   18.40
# 240               30.2   27.96
# 360               29.0   28.00
# 480               33.8   18.52
# ...                ...     ...
# 3836              51.7   19.48
# 11036             52.5   12.36
# 3837              51.9   19.20
# 3838              52.4   18.88
# 3839              52.9   18.60
#
# [10931 rows x 6 columns]

# %%
# group by country 
# get max life_exp for each group 
df.groupby('country').life_expectancy.max().reset_index(name = "max_life_exp")
# Out:
#                  country  max_life_exp
# 0            Afghanistan          64.1
# 1                Albania          78.5
# 2                Algeria          78.1
# 3                 Angola          65.0
# 4    Antigua and Barbuda          77.3
# ..                   ...           ...
# 179            Venezuela          75.3
# 180              Vietnam          74.7
# 181                Yemen          69.0
# 182               Zambia          64.0
# 183             Zimbabwe          62.8
#
# [184 rows x 2 columns]

# %% [markdown]
# For each question here, return a pandas series.
# Find the maximum income for each type in the occupation_prestige data.
# Find the average prestige for each type.
# Find the lowest percentage of women for each type.

# %%
df_op.groupby('type').income.max()
# Out:
# type
# bc       8895
# prof    25879
# wc       8780
# Name: income, dtype: int64

# %%
df_op.groupby('type').prestige.mean()
# Out:
# type
# bc      35.527273
# prof    67.848387
# wc      42.243478
# Name: prestige, dtype: float64

# %%
df_op.groupby('type').women.min()
# Out:
# type
# bc      0.52
# prof    0.58
# wc      3.16
# Name: women, dtype: float64

# %%
df.isna().sum()
# Out:
# country              0
# year                 0
# fertility_rate       0
# GDP                 14
# life_expectancy    184
# f_rate               0
# dtype: int64

# %%
#missing values 
df.dropna().shape
# Out:
# (21882, 6)

# %%
df.dropna(subset = ['life_expectancy']).isna().sum()
# Out:
# country             0
# year                0
# fertility_rate      0
# GDP                14
# life_expectancy     0
# f_rate              0
# dtype: int64

# %%
#imputation fill them with values 
df.fillna(
    value = 0)
# Out:
#                    country  year  fertility_rate     GDP  life_expectancy  \
# 0              Afghanistan  1900          112.00  1090.0             29.4
# 120                Albania  1900           73.60  1220.0             35.4
# 240                Algeria  1900          111.84  1750.0             30.2
# 360                 Angola  1900          112.00   958.0             29.0
# 480    Antigua and Barbuda  1900           74.08  1300.0             33.8
# ...                    ...   ...             ...     ...              ...
# 21599            Venezuela  2019           36.00  9720.0             75.1
# 21719              Vietnam  2019           31.04  6970.0             74.7
# 21839                Yemen  2019           59.04  2340.0             68.1
# 21959               Zambia  2019           76.96  3700.0             64.0
# 22079             Zimbabwe  2019           56.48  2390.0             62.0
#
#        f_rate
# 0       28.00
# 120     18.40
# 240     27.96
# 360     28.00
# 480     18.52
# ...       ...
# 21599    9.00
# 21719    7.76
# 21839   14.76
# 21959   19.24
# 22079   14.12
#
# [22080 rows x 6 columns]

# %%
df.fillna(value = {
    'life_expectancy': 0,
    'income_per_person':50})
# Out:
#                    country  year  fertility_rate     GDP  life_expectancy  \
# 0              Afghanistan  1900          112.00  1090.0             29.4
# 120                Albania  1900           73.60  1220.0             35.4
# 240                Algeria  1900          111.84  1750.0             30.2
# 360                 Angola  1900          112.00   958.0             29.0
# 480    Antigua and Barbuda  1900           74.08  1300.0             33.8
# ...                    ...   ...             ...     ...              ...
# 21599            Venezuela  2019           36.00  9720.0             75.1
# 21719              Vietnam  2019           31.04  6970.0             74.7
# 21839                Yemen  2019           59.04  2340.0             68.1
# 21959               Zambia  2019           76.96  3700.0             64.0
# 22079             Zimbabwe  2019           56.48  2390.0             62.0
#
#        f_rate
# 0       28.00
# 120     18.40
# 240     27.96
# 360     28.00
# 480     18.52
# ...       ...
# 21599    9.00
# 21719    7.76
# 21839   14.76
# 21959   19.24
# 22079   14.12
#
# [22080 rows x 6 columns]

# %%
df.fillna(value = {
    'life_expectancy': df.life_expectancy.mean(),
    'income_per_person':df.GDP.median()
})
# Out:
#                    country  year  fertility_rate     GDP  life_expectancy  \
# 0              Afghanistan  1900          112.00  1090.0             29.4
# 120                Albania  1900           73.60  1220.0             35.4
# 240                Algeria  1900          111.84  1750.0             30.2
# 360                 Angola  1900          112.00   958.0             29.0
# 480    Antigua and Barbuda  1900           74.08  1300.0             33.8
# ...                    ...   ...             ...     ...              ...
# 21599            Venezuela  2019           36.00  9720.0             75.1
# 21719              Vietnam  2019           31.04  6970.0             74.7
# 21839                Yemen  2019           59.04  2340.0             68.1
# 21959               Zambia  2019           76.96  3700.0             64.0
# 22079             Zimbabwe  2019           56.48  2390.0             62.0
#
#        f_rate
# 0       28.00
# 120     18.40
# 240     27.96
# 360     28.00
# 480     18.52
# ...       ...
# 21599    9.00
# 21719    7.76
# 21839   14.76
# 21959   19.24
# 22079   14.12
#
# [22080 rows x 6 columns]

# %%
#groupby too mmean of the group

# %%
mean_per_country = df.groupby('country').life_expectancy.transform('mean')

df.fillna(value = {
    'life_expectancy': mean_per_country,
    'income_per_person':df.GDP.median()
})
# Out:
#                    country  year  fertility_rate     GDP  life_expectancy  \
# 0              Afghanistan  1900          112.00  1090.0             29.4
# 120                Albania  1900           73.60  1220.0             35.4
# 240                Algeria  1900          111.84  1750.0             30.2
# 360                 Angola  1900          112.00   958.0             29.0
# 480    Antigua and Barbuda  1900           74.08  1300.0             33.8
# ...                    ...   ...             ...     ...              ...
# 21599            Venezuela  2019           36.00  9720.0             75.1
# 21719              Vietnam  2019           31.04  6970.0             74.7
# 21839                Yemen  2019           59.04  2340.0             68.1
# 21959               Zambia  2019           76.96  3700.0             64.0
# 22079             Zimbabwe  2019           56.48  2390.0             62.0
#
#        f_rate
# 0       28.00
# 120     18.40
# 240     27.96
# 360     28.00
# 480     18.52
# ...       ...
# 21599    9.00
# 21719    7.76
# 21839   14.76
# 21959   19.24
# 22079   14.12
#
# [22080 rows x 6 columns]

# %% [markdown]
# Find which columns have missing values in occupation_prestige.
#
# Replace all the missing values in type with "other". Check that this change has been made in the occupation_prestige.
#
# Find the average of women.
#
# Without changing or removing missing values.
#
# With all the missing values changed to 0.
#
# With all the missing values dropped.

# %%
df_op.isna().sum()
# Out:
# job          0
# education    0
# income       0
# women        5
# prestige     0
# census       0
# type         4
# dtype: int64

# %%
df_op.fillna(value = {
    'type': "other"
}
)
# Out:
#                      job  education  income  women  prestige  census  type
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
# 99          longshoremen       8.37    4753    NaN      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 101          bookbinders       8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 7 columns]

# %%
df_op.women.mean()
# Out:
# 30.47278350515466

# %%
df_op.fillna(value = {
    'women': 0
}
).women.mean()
# Out:
# 28.979019607843156

# %%
df_op.dropna(subset = ['women']).women.mean()
# Out:
# 30.47278350515466

# %%
(df_op.fillna(value = {
    'women': 0
}
).loc[:,['job', 'income', 'women', 'type']]
.assign(income_1000 = df_op.income/1000)
.groupby('type')
.income_1000
.mean()
)
# Out:
# type
# bc       5.374136
# prof    10.559452
# wc       5.052304
# Name: income_1000, dtype: float64
